# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('datasets/laptop_prices.csv')

# %%
print(df.shape)
df.sample(25)
# Out:
# (1275, 23)
#       Company                               Product            TypeName  \
# 10         HP                                250 G6            Notebook
# 476      Dell                       Precision M5520         Workstation
# 555      Asus  A541NA-GO342 (N3350/4GB/500GB/Linux)            Notebook
# 1057     Acer                        Aspire ES1-523            Notebook
# 316        HP                          Spectre x360  2 in 1 Convertible
# 97       Dell                         Inspiron 3567            Notebook
# 767      Dell                         Inspiron 7559              Gaming
# 1034       HP                         EliteBook 850            Notebook
# 317    Lenovo                           ThinkPad 13            Notebook
# 1040   Lenovo                        Yoga 500-15ISK  2 in 1 Convertible
# 411    Lenovo                        Thinkpad T470p           Ultrabook
# 578       MSI                          GT73VR Titan              Gaming
# ...

# %%
df[df['Company']=='Apple']['Product'].value_counts()
# Out:
# Product
# MacBook Pro    10
# MacBook 12"     6
# MacBook Air     3
# Macbook Air     2
# Name: count, dtype: int64

# %%
df[df['Product']=='MacBook 12"']
# Out:
#      Company      Product   TypeName  Inches  Ram        OS  Weight  \
# 14     Apple  MacBook 12"  Ultrabook    12.0    8     macOS    0.92
# 81     Apple  MacBook 12"  Ultrabook    12.0    8     macOS    0.92
# 794    Apple  MacBook 12"  Ultrabook    12.0    8  Mac OS X    0.92
# 1069   Apple  MacBook 12"  Ultrabook    12.0    8  Mac OS X    0.92
# 1193   Apple  MacBook 12"  Ultrabook    12.0    8  Mac OS X    0.92
# 1210   Apple  MacBook 12"  Ultrabook    12.0    8  Mac OS X    0.92
#
#       Price_euros    Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq  \
# 14         1262.4  Standard     2304  ...            Yes       Intel      1.2
# 81         1510.0  Standard     2304  ...            Yes       Intel      1.3
# 794        1165.0  Standard     2304  ...            Yes       Intel      1.2
# 1069       1300.0  Standard     2304  ...            Yes       Intel      1.1
# 1193       1163.0  Standard     2304  ...            Yes       Intel      1.1
# ...

# %%
df[df['Product']=='MacBook Pro']
# Out:
#     Company      Product   TypeName  Inches  Ram        OS  Weight  \
# 0     Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
# 3     Apple  MacBook Pro  Ultrabook    15.4   16     macOS    1.83
# 4     Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
# 6     Apple  MacBook Pro  Ultrabook    15.4   16  Mac OS X    2.04
# 12    Apple  MacBook Pro  Ultrabook    15.4   16     macOS    1.83
# 15    Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
# 17    Apple  MacBook Pro  Ultrabook    15.4   16     macOS    1.83
# 45    Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
# 249   Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
# 270   Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
#
#      Price_euros    Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq  \
# 0        1339.69  Standard     2560  ...            Yes       Intel      2.3
# ...

# %%
df[df['Company']=='Apple']['Product'].str.title().str.strip()
# Out:
# 0       Macbook Pro
# 1       Macbook Air
# 3       Macbook Pro
# 4       Macbook Pro
# 6       Macbook Pro
# 7       Macbook Air
# 12      Macbook Pro
# 14      Macbook 12"
# 15      Macbook Pro
# 17      Macbook Pro
# 26      Macbook Air
# 34      Macbook Air
# 45      Macbook Pro
# 81      Macbook 12"
# 249     Macbook Pro
# 270     Macbook Pro
# 794     Macbook 12"
# 1069    Macbook 12"
# 1193    Macbook 12"
# 1210    Macbook 12"
# 1234    Macbook Air
# Name: Product, dtype: object

# %%
df['Product']=df['Product'].replace("Macbook Air","MacBook Air")
df['Product']=df['Product'].replace('MacBook 12"',"MacBook Air")

# %%
df[df['Company']=='Apple']['Product'].value_counts()
# Out:
# Product
# MacBook Air    11
# MacBook Pro    10
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(25)
# Out:
#       Company                                  Product            TypeName  \
# 1200     Dell                            Inspiron 5567            Notebook
# 947    Lenovo                        IdeaPad 310-15IKB            Notebook
# 269    Lenovo  V330-15IKB (i7-8550U/8GB/256GB/FHD/W10)            Notebook
# 930    Lenovo                        IdeaPad 320-15IAP            Notebook
# 1020     Dell                            Inspiron 5568  2 in 1 Convertible
# 502    Lenovo                           Yoga 920-13IKB  2 in 1 Convertible
# 413      Acer                                Aspire R7  2 in 1 Convertible
# 82         HP                              ProBook 440            Notebook
# 1146       HP                            EliteBook 820           Ultrabook
# 1080   Lenovo                          Yoga 900S-12ISK           Ultrabook
# 1234    Apple                              MacBook Air           Ultrabook
# ...

# %%
df['type_name']=df['Product'].str.split("(").str.get(0).str.strip()

# %%
df.sample(25)
# Out:
#       Company                                      Product  \
# 1076   Lenovo                            Ideapad 700-15ISK
# 255      Dell                                  Vostro 5370
# 34      Apple                                  MacBook Air
# 163    Lenovo                           Legion Y520-15IKBN
# 995      Asus                       ZenBook UX310UA-FB485T
# 1044       HP                                EliteBook 840
# 220      Dell                                Inspiron 3576
# 608    Lenovo                               Yoga 720-15IKB
# 993    Lenovo                                ThinkPad T560
# 390      Asus                           Rog GL753VD-GC042T
# 1091       HP                                       250 G6
# 238      Asus                            ROG G703VI-E5062T
# 705      Dell                                  Vostro 5568
# 430   Samsung                                 Chromebook 3
# 779      Asus                                 Vivobook Max
# ...

# %%
df['new_type_name']=df.apply(lambda x : x['type_name'] if x['type_name']=='MacBook Pro' or x['type_name']=='MacBook Air' else x['TypeName'], axis=1)

# %%
df[df['Company']=='Apple']
# Out:
#      Company      Product   TypeName  Inches  Ram        OS  Weight  \
# 0      Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
# 1      Apple  MacBook Air  Ultrabook    13.3    8     macOS    1.34
# 3      Apple  MacBook Pro  Ultrabook    15.4   16     macOS    1.83
# 4      Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
# 6      Apple  MacBook Pro  Ultrabook    15.4   16  Mac OS X    2.04
# 7      Apple  MacBook Air  Ultrabook    13.3    8     macOS    1.34
# 12     Apple  MacBook Pro  Ultrabook    15.4   16     macOS    1.83
# 14     Apple  MacBook Air  Ultrabook    12.0    8     macOS    0.92
# 15     Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
# 17     Apple  MacBook Pro  Ultrabook    15.4   16     macOS    1.83
# 26     Apple  MacBook Air  Ultrabook    13.3    8  Mac OS X    1.35
# 34     Apple  MacBook Air  Ultrabook    13.3    8  Mac OS X    1.35
# 45     Apple  MacBook Pro  Ultrabook    13.3    8     macOS    1.37
# ...

# %%
df.sample(25)
# Out:
#       Company                              Product            TypeName  \
# 360        HP                               250 G6            Notebook
# 419    Lenovo                        ThinkPad E480           Ultrabook
# 240    Lenovo                    IdeaPad 320-15ISK            Notebook
# 73        MSI                           GL72M 7RDX              Gaming
# 565      Dell                               XPS 13           Ultrabook
# 923   Toshiba                      Tecra Z50-C-140            Notebook
# 171        HP  17-bs001nv (i5-7200U/6GB/2TB/Radeon            Notebook
# 811       MSI                          GE72MVR 7RG              Gaming
# 930    Lenovo                    IdeaPad 320-15IAP            Notebook
# 844        HP                        EliteBook 840           Ultrabook
# 1260   Lenovo                       Yoga 500-14IBD  2 in 1 Convertible
# 1105     Dell                       Latitude E5270           Ultrabook
# ...

# %%
df.drop(columns=['TypeName','type_name','Product'], inplace=True)

# %%
df.head()
# Out:
#   Company  Inches  Ram     OS  Weight  Price_euros    Screen  ScreenW  \
# 0   Apple    13.3    8  macOS    1.37      1339.69  Standard     2560
# 1   Apple    13.3    8  macOS    1.34       898.94  Standard     1440
# 2      HP    15.6    8  No OS    1.86       575.00   Full HD     1920
# 3   Apple    15.4   16  macOS    1.83      2537.45  Standard     2880
# 4   Apple    13.3    8  macOS    1.37      1803.60  Standard     2560
#
#    ScreenH Touchscreen  ... CPU_company CPU_freq      CPU_model  \
# 0     1600          No  ...       Intel      2.3        Core i5
# 1      900          No  ...       Intel      1.8        Core i5
# 2     1080          No  ...       Intel      2.5  Core i5 7200U
# 3     1800          No  ...       Intel      2.7        Core i7
# 4     1600          No  ...       Intel      3.1        Core i5
#
#    PrimaryStorage SecondaryStorage  PrimaryStorageType  SecondaryStorageType  \
# 0             128                0                 SSD                    No
# ...

# %%
df.columns = df.columns.str.lower().str.replace(" ","")

# %%
df.columns
# Out:
# Index(['company', 'inches', 'ram', 'os', 'weight', 'price_euros', 'screen',
#        'screenw', 'screenh', 'touchscreen', 'ipspanel', 'retinadisplay',
#        'cpu_company', 'cpu_freq', 'cpu_model', 'primarystorage',
#        'secondarystorage', 'primarystoragetype', 'secondarystoragetype',
#        'gpu_company', 'gpu_model', 'new_type_name'],
#       dtype='object')

# %%
numbers_columns=df.select_dtypes(include=[np.number]).columns
numbers_columns
# Out:
# Index(['inches', 'ram', 'weight', 'price_euros', 'screenw', 'screenh',
#        'cpu_freq', 'primarystorage', 'secondarystorage'],
#       dtype='object')

# %%
df[numbers_columns].corr()['price_euros']
# Out:
# inches              0.066608
# ram                 0.740287
# weight              0.211883
# price_euros         1.000000
# screenw             0.552491
# screenh             0.548529
# cpu_freq            0.428847
# primarystorage     -0.124775
# secondarystorage    0.291207
# Name: price_euros, dtype: float64

# %%
df['ppi']=round(((df['screenw']**2) + (df['screenh']**2))**0.5 / (df['inches']),2)

# %%
numbers_columns=df.select_dtypes(include=[np.number]).columns
numbers_columns
# Out:
# Index(['inches', 'ram', 'weight', 'price_euros', 'screenw', 'screenh',
#        'cpu_freq', 'primarystorage', 'secondarystorage', 'ppi'],
#       dtype='object')

# %%
df[numbers_columns].corr()['price_euros']
# Out:
# inches              0.066608
# ram                 0.740287
# weight              0.211883
# price_euros         1.000000
# screenw             0.552491
# screenh             0.548529
# cpu_freq            0.428847
# primarystorage     -0.124775
# secondarystorage    0.291207
# ppi                 0.470050
# Name: price_euros, dtype: float64

# %%
df.drop(columns=['screenw','screenh','inches','primarystorage'], inplace=True)

# %%
df.head()
# Out:
#   company  ram     os  weight  price_euros    screen touchscreen ipspanel  \
# 0   Apple    8  macOS    1.37      1339.69  Standard          No      Yes
# 1   Apple    8  macOS    1.34       898.94  Standard          No       No
# 2      HP    8  No OS    1.86       575.00   Full HD          No       No
# 3   Apple   16  macOS    1.83      2537.45  Standard          No      Yes
# 4   Apple    8  macOS    1.37      1803.60  Standard          No      Yes
#
#   retinadisplay cpu_company  cpu_freq      cpu_model  secondarystorage  \
# 0           Yes       Intel       2.3        Core i5                 0
# 1            No       Intel       1.8        Core i5                 0
# 2            No       Intel       2.5  Core i5 7200U                 0
# 3           Yes       Intel       2.7        Core i7                 0
# 4           Yes       Intel       3.1        Core i5                 0
#
#   primarystoragetype secondarystoragetype gpu_company               gpu_model  \
# ...

# %%
df['gpu_name'] = df.apply(lambda x : x['gpu_company'] + " " + x['gpu_model'], axis=1)

# %%
df.head()
# Out:
#   company  ram     os  weight  price_euros    screen touchscreen ipspanel  \
# 0   Apple    8  macOS    1.37      1339.69  Standard          No      Yes
# 1   Apple    8  macOS    1.34       898.94  Standard          No       No
# 2      HP    8  No OS    1.86       575.00   Full HD          No       No
# 3   Apple   16  macOS    1.83      2537.45  Standard          No      Yes
# 4   Apple    8  macOS    1.37      1803.60  Standard          No      Yes
#
#   retinadisplay cpu_company  cpu_freq      cpu_model  secondarystorage  \
# 0           Yes       Intel       2.3        Core i5                 0
# 1            No       Intel       1.8        Core i5                 0
# 2            No       Intel       2.5  Core i5 7200U                 0
# 3           Yes       Intel       2.7        Core i7                 0
# 4           Yes       Intel       3.1        Core i5                 0
#
#   primarystoragetype secondarystoragetype gpu_company               gpu_model  \
# ...

# %%
df.drop(columns=['gpu_company','gpu_model','screen','os'], inplace=True)

# %%
df['company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='company'>

# %%
sns.histplot(df, x='ram', kde=True)
# Out:
# <Axes: xlabel='ram', ylabel='Count'>

# %%
df['ipspanel'] = df['ipspanel'].map({'Yes':1,'No':0}).astype(int)
df['retinadisplay'] = df['retinadisplay'].map({'Yes':1,'No':0}).astype(int)
df['touchscreen'] = df['touchscreen'].map({'Yes':1,'No':0}).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   company               1275 non-null   object
#  1   ram                   1275 non-null   int64
#  2   weight                1275 non-null   float64
#  3   price_euros           1275 non-null   float64
#  4   touchscreen           1275 non-null   int64
#  5   ipspanel              1275 non-null   int64
#  6   retinadisplay         1275 non-null   int64
#  7   cpu_company           1275 non-null   object
#  8   cpu_freq              1275 non-null   float64
#  9   cpu_model             1275 non-null   object
#  10  secondarystorage      1275 non-null   int64
#  11  primarystoragetype    1275 non-null   object
#  12  secondarystoragetype  1275 non-null   object
#  13  new_type_name         1275 non-null   object
#  14  ppi                   1275 non-null   float64
# ...

# %%
df[df.select_dtypes(include=[np.number]).columns].corr()['price_euros']
# Out:
# ram                 0.740287
# weight              0.211883
# price_euros         1.000000
# touchscreen         0.188886
# ipspanel            0.250737
# retinadisplay       0.086775
# cpu_freq            0.428847
# secondarystorage    0.291207
# ppi                 0.470050
# Name: price_euros, dtype: float64

# %%
number_columns_list=df.select_dtypes(include=[np.number]).columns
number_columns_list
# Out:
# Index(['ram', 'weight', 'price_euros', 'touchscreen', 'ipspanel',
#        'retinadisplay', 'cpu_freq', 'secondarystorage', 'ppi'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def check_vif(data):
    df = pd.DataFrame()
    df['column'] = data.columns
    df['vif'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return df
check_vif(df[number_columns_list].drop('price_euros',axis=1))
# Out:
#              column        vif
# 0               ram   5.752003
# 1            weight  12.878139
# 2       touchscreen   1.622363
# 3          ipspanel   1.572486
# 4     retinadisplay   1.137468
# 5          cpu_freq  20.089587
# 6  secondarystorage   1.567926
# 7               ppi  12.922607

# %%
df.drop('cpu_freq', axis=1, inplace=True)

# %%
number_columns_list=df.select_dtypes(include=[np.number]).columns
number_columns_list
# Out:
# Index(['ram', 'weight', 'price_euros', 'touchscreen', 'ipspanel',
#        'retinadisplay', 'secondarystorage', 'ppi'],
#       dtype='object')

# %%
check_vif(df[number_columns_list].drop('price_euros',axis=1))
# Out:
#              column       vif
# 0               ram  5.701911
# 1            weight  7.569026
# 2       touchscreen  1.594537
# 3          ipspanel  1.568926
# 4     retinadisplay  1.126123
# 5  secondarystorage  1.538590
# 6               ppi  8.168815

# %%
df[df.select_dtypes(include=[np.number]).columns].corr()['price_euros']
# Out:
# ram                 0.740287
# weight              0.211883
# price_euros         1.000000
# touchscreen         0.188886
# ipspanel            0.250737
# retinadisplay       0.086775
# secondarystorage    0.291207
# ppi                 0.470050
# Name: price_euros, dtype: float64

# %%
df.drop(['retinadisplay'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   company  ram  weight  price_euros  touchscreen  ipspanel cpu_company  \
# 0   Apple    8    1.37      1339.69            0         1       Intel
# 1   Apple    8    1.34       898.94            0         0       Intel
# 2      HP    8    1.86       575.00            0         0       Intel
# 3   Apple   16    1.83      2537.45            0         1       Intel
# 4   Apple    8    1.37      1803.60            0         1       Intel
#
#        cpu_model  secondarystorage primarystoragetype secondarystoragetype  \
# 0        Core i5                 0                SSD                   No
# 1        Core i5                 0      Flash Storage                   No
# 2  Core i5 7200U                 0                SSD                   No
# 3        Core i7                 0                SSD                   No
# 4        Core i5                 0                SSD                   No
#
#   new_type_name     ppi                      gpu_name
# ...

# %%
list_screen = ['touchscreen','ipspanel']
fig, axes = plt.subplots(1,2, figsize=(10,5))
axes = axes.flatten()
for idx, column in enumerate(list_screen):
    sns.countplot(df, x=column, ax=axes[idx])
    axes[idx].set_title(column)
plt.show()

# %%
df['cpu_company'].value_counts()
# Out:
# cpu_company
# Intel      1214
# AMD          60
# Samsung       1
# Name: count, dtype: int64

# %%
df[df['cpu_company']=='Samsung']
# Out:
#       company  ram  weight  price_euros  touchscreen  ipspanel cpu_company  \
# 1191  Samsung    4    1.15        659.0            1         1     Samsung
#
#            cpu_model  secondarystorage primarystoragetype  \
# 1191  Cortex A72&A53                 0      Flash Storage
#
#      secondarystoragetype       new_type_name     ppi           gpu_name
# 1191                   No  2 in 1 Convertible  234.51  ARM Mali T860 MP4

# %%
df['cpu_company'] = df['cpu_company'].replace("Samsung","Intel")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   company               1275 non-null   object
#  1   ram                   1275 non-null   int64
#  2   weight                1275 non-null   float64
#  3   price_euros           1275 non-null   float64
#  4   touchscreen           1275 non-null   int64
#  5   ipspanel              1275 non-null   int64
#  6   cpu_company           1275 non-null   object
#  7   cpu_model             1275 non-null   object
#  8   secondarystorage      1275 non-null   int64
#  9   primarystoragetype    1275 non-null   object
#  10  secondarystoragetype  1275 non-null   object
#  11  new_type_name         1275 non-null   object
#  12  ppi                   1275 non-null   float64
#  13  gpu_name              1275 non-null   object
# dtypes: float64(3), int64(4), object(7)
# ...

# %%
df.drop(columns=['secondarystoragetype'], inplace=True)

# %%
df.head()
# Out:
#   company  ram  weight  price_euros  touchscreen  ipspanel cpu_company  \
# 0   Apple    8    1.37      1339.69            0         1       Intel
# 1   Apple    8    1.34       898.94            0         0       Intel
# 2      HP    8    1.86       575.00            0         0       Intel
# 3   Apple   16    1.83      2537.45            0         1       Intel
# 4   Apple    8    1.37      1803.60            0         1       Intel
#
#        cpu_model  secondarystorage primarystoragetype new_type_name     ppi  \
# 0        Core i5                 0                SSD   MacBook Pro  226.98
# 1        Core i5                 0      Flash Storage   MacBook Air  127.68
# 2  Core i5 7200U                 0                SSD      Notebook  141.21
# 3        Core i7                 0                SSD   MacBook Pro  220.53
# 4        Core i5                 0                SSD   MacBook Pro  226.98
#
#                        gpu_name
# 0  Intel Iris Plus Graphics 640
# ...

# %%
df['cpu_name'] = df.apply(lambda x : x['cpu_company'] + " " + x['cpu_model'], axis=1)

# %%
df.head()
# Out:
#   company  ram  weight  price_euros  touchscreen  ipspanel cpu_company  \
# 0   Apple    8    1.37      1339.69            0         1       Intel
# 1   Apple    8    1.34       898.94            0         0       Intel
# 2      HP    8    1.86       575.00            0         0       Intel
# 3   Apple   16    1.83      2537.45            0         1       Intel
# 4   Apple    8    1.37      1803.60            0         1       Intel
#
#        cpu_model  secondarystorage primarystoragetype new_type_name     ppi  \
# 0        Core i5                 0                SSD   MacBook Pro  226.98
# 1        Core i5                 0      Flash Storage   MacBook Air  127.68
# 2  Core i5 7200U                 0                SSD      Notebook  141.21
# 3        Core i7                 0                SSD   MacBook Pro  220.53
# 4        Core i5                 0                SSD   MacBook Pro  226.98
#
#                        gpu_name             cpu_name
# ...

# %%
df.drop(columns=['cpu_company','cpu_model','weight','touchscreen'], inplace=True)

# %%
df.head()
# Out:
#   company  ram  price_euros  ipspanel  secondarystorage primarystoragetype  \
# 0   Apple    8      1339.69         1                 0                SSD
# 1   Apple    8       898.94         0                 0      Flash Storage
# 2      HP    8       575.00         0                 0                SSD
# 3   Apple   16      2537.45         1                 0                SSD
# 4   Apple    8      1803.60         1                 0                SSD
#
#   new_type_name     ppi                      gpu_name             cpu_name
# 0   MacBook Pro  226.98  Intel Iris Plus Graphics 640        Intel Core i5
# 1   MacBook Air  127.68        Intel HD Graphics 6000        Intel Core i5
# 2      Notebook  141.21         Intel HD Graphics 620  Intel Core i5 7200U
# 3   MacBook Pro  220.53            AMD Radeon Pro 455        Intel Core i7
# 4   MacBook Pro  226.98  Intel Iris Plus Graphics 650        Intel Core i5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   company             1275 non-null   object
#  1   ram                 1275 non-null   int64
#  2   price_euros         1275 non-null   float64
#  3   ipspanel            1275 non-null   int64
#  4   secondarystorage    1275 non-null   int64
#  5   primarystoragetype  1275 non-null   object
#  6   new_type_name       1275 non-null   object
#  7   ppi                 1275 non-null   float64
#  8   gpu_name            1275 non-null   object
#  9   cpu_name            1275 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 99.7+ KB

# %%
df['secondarystorage'].value_counts()
# Out:
# secondarystorage
# 0       1067
# 1024     187
# 2048      15
# 256        3
# 500        2
# 512        1
# Name: count, dtype: int64

# %%
df['ipspanel'] = df['ipspanel'].astype('object')

# %%
list_numerical=df.select_dtypes(include=['float64', 'int64']).columns
list_numerical
# Out:
# Index(['ram', 'price_euros', 'secondarystorage', 'ppi'], dtype='object')

# %%
fig, axes = plt.subplots(2,3, figsize=(15,10))
axes = axes.flatten()
for idx, col in enumerate(list_numerical):
    sns.boxplot(df , y=col, ax = axes[idx])
    axes[idx].set_title(col)
# fig.delaxes(axes[])
plt.show()

# %%
df[df['ram']>40]
# Out:
#      company  ram  price_euros ipspanel  secondarystorage primarystoragetype  \
# 1066    Asus   64       3975.0        1                 0                SSD
#
#      new_type_name     ppi                 gpu_name              cpu_name
# 1066        Gaming  127.34  Nvidia GeForce GTX 980   Intel Core i7 6820HK

# %%
list_categories = df.select_dtypes(include=['object']).columns
list_categories
# Out:
# Index(['company', 'ipspanel', 'primarystoragetype', 'new_type_name',
#        'gpu_name', 'cpu_name'],
#       dtype='object')

# %%
list_numerical = df.select_dtypes(include=['float64', 'int64']).columns
list_numerical
# Out:
# Index(['ram', 'price_euros', 'secondarystorage', 'ppi'], dtype='object')

# %%
df.head()
# Out:
#   company  ram  price_euros ipspanel  secondarystorage primarystoragetype  \
# 0   Apple    8      1339.69        1                 0                SSD
# 1   Apple    8       898.94        0                 0      Flash Storage
# 2      HP    8       575.00        0                 0                SSD
# 3   Apple   16      2537.45        1                 0                SSD
# 4   Apple    8      1803.60        1                 0                SSD
#
#   new_type_name     ppi                      gpu_name             cpu_name
# 0   MacBook Pro  226.98  Intel Iris Plus Graphics 640        Intel Core i5
# 1   MacBook Air  127.68        Intel HD Graphics 6000        Intel Core i5
# 2      Notebook  141.21         Intel HD Graphics 620  Intel Core i5 7200U
# 3   MacBook Pro  220.53            AMD Radeon Pro 455        Intel Core i7
# 4   MacBook Pro  226.98  Intel Iris Plus Graphics 650        Intel Core i5

# %%
df['gpu_name'].value_counts()
# Out:
# gpu_name
# Intel HD Graphics 620      279
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df = df[df['gpu_name']!="ARM Mali T860 MP4"]

# %%
def gpu_name(x):
    amd_keywords = ["AMD Radeon R2","AMD Radeon R3", "AMD Radeon R5", "AMD Radeon R7", "AMD Radeon R9", "AMD Radeon RX","AMD R4 Graphics","AMD Radeon R4 Graphics","AMD Radeon R2 Graphics","AMD Radeon R4"]
    if any(keyword in x for keyword in amd_keywords):
        return "AMD Radeon RX"
    intel_keywords = ["Intel HD Graphics", "Intel UHD Graphics ", "Intel Iris Plus Graphics ", "Intel HD Graphics", "Intel Iris Graphics ","Intel Iris Pro Graphics","Intel Graphics 620"]
    if any(keyword in x for keyword in intel_keywords):
        return "Intel Onboard Graphics"
    GTX_9M_list = ["Nvidia GeForce GTX 950M","Nvidia GeForce 920MX","Nvidia GeForce 930MX","Nvidia GeForce 940MX","Nvidia GeForce GTX 960M","Nvidia GeForce GTX 980M","Nvidia GeForce GTX 950M","Nvidia GeForce 930M","Nvidia GeForce GT 940MX","Nvidia GeForce GTX 970M","Nvidia GeForce 920MX","Nvidia GeForce 930MX","Nvidia GeForce GTX 965M","Nvidia GeForce 920M","Nvidia GeForce GTX 940MX","Nvidia GeForce GTX 960","Nvidia GeForce GTX 930MX","Nvidia GeForce GTX 980","Nvidia GeForce 960M","Nvidia GeForce 920","Nvidia GeForce 940M","Nvidia GeForce GTX 940M","Nvidia GTX 980 SLI"]
    if any(keyword in x for keyword in GTX_9M_list):
        return "Nvidia GeForce GTX 9XX"
    list_amd_5xx = ["AMD Radeon 530", "AMD Radeon 520", "AMD Radeon 540"]
    if any(keyword in x for keyword in list_amd_5xx):
        return "AMD Radeon 5XX"
    list_MX = ["Nvidia GeForce MX130","Nvidia GeForce 150MX","Nvidia GeForce MX150"]
    if any(keyword in x for keyword in list_MX):
        return "Nvidia GeForce MX"
    if "AMD Radeon Pro " in x:
        return "AMD Radeon Pro"
    if "Nvidia GeForce GTX1080" in x:
        return "Nvidia GeForce GTX 1080"
    if "Nvidia GeForce GTX1050 Ti" in x:
        return "Nvidia GeForce GTX 1050 Ti"
    if "Nvidia GeForce GTX1060 " in x:
        return "Nvidia GeForce GTX 1060"
    if "Nvidia GeForce GTX 1050Ti" in x:
        return "Nvidia GeForce GTX 1050 Ti"
    if "Nvidia Quadro " in x:
        return "Nvidia Quadro Graphics"
    if "AMD FirePro " in x:
        return "AMD FirePro"
    if "Nvidia GeForce GTX1060" in x:
        return "Nvidia GeForce GTX 1060"
    if "Nvidia GeForce GTX 1070M" in x:
        return "Nvidia GeForce GTX 1070"
    if "Nvidia GeForce GTX 1050M" in x:
        return "Nvidia GeForce GTX 1050"
    if "AMD R17M-M1-70" in x:
        return "AMD Radeon Pro"
    if "AMD FirePro" in x:
        return "AMD Radeon Pro"
    else :
        return x

# %%
df['gpu_name'] = df['gpu_name'].apply(gpu_name)

# %%
df.head()
# Out:
#   company  ram  price_euros ipspanel  secondarystorage primarystoragetype  \
# 0   Apple    8      1339.69        1                 0                SSD
# 1   Apple    8       898.94        0                 0      Flash Storage
# 2      HP    8       575.00        0                 0                SSD
# 3   Apple   16      2537.45        1                 0                SSD
# 4   Apple    8      1803.60        1                 0                SSD
#
#   new_type_name     ppi                gpu_name             cpu_name
# 0   MacBook Pro  226.98  Intel Onboard Graphics        Intel Core i5
# 1   MacBook Air  127.68  Intel Onboard Graphics        Intel Core i5
# 2      Notebook  141.21  Intel Onboard Graphics  Intel Core i5 7200U
# 3   MacBook Pro  220.53          AMD Radeon Pro        Intel Core i7
# 4   MacBook Pro  226.98  Intel Onboard Graphics        Intel Core i5

# %%
def chip(x):
    list_intel_others = ["Intel Core M ","Intel Atom ", "Intel Xeon ","Intel Core M"]
    if any(word in x for word in list_intel_others):
        return "Intel others"
    list_AMD_A = ["AMD A9","AMD A6","AMD A12","AMD E-Series","AMD A4-Series","AMD A10-Series","AMD A8-Series"]
    if any(word in x for word in list_AMD_A):
        return "AMD-Series"
    if "Intel Core i5 " in x :
        return "Intel Core i5"
    if "Intel Core i7 " in x :
        return "Intel Core i7"
    if "Intel Core i3 " in x:
        return "Intel Core i3"
    if "Intel Celeron Dual Core " in x:
        return "Intel Celeron Dual Core"
    if "Intel Pentium Quad Core " in x :
        return "Intel Celeron Dual Core"
    if "Intel Pentium Dual Core " in x:
        return "Intel Celeron Dual Core"
    if "Intel Celeron Quad Core " in x:
        return "Intel Celeron Dual Core"
    if "AMD Ryzen" in x:
        return "AMD Ryzen"
    if "AMD FX" in x:
        return "AMD FX"
    else :
        return x

# %%
df['cpu_name'] = df['cpu_name'].apply(chip)

# %%
df.head()
# Out:
#   company  ram  price_euros ipspanel  secondarystorage primarystoragetype  \
# 0   Apple    8      1339.69        1                 0                SSD
# 1   Apple    8       898.94        0                 0      Flash Storage
# 2      HP    8       575.00        0                 0                SSD
# 3   Apple   16      2537.45        1                 0                SSD
# 4   Apple    8      1803.60        1                 0                SSD
#
#   new_type_name     ppi                gpu_name       cpu_name
# 0   MacBook Pro  226.98  Intel Onboard Graphics  Intel Core i5
# 1   MacBook Air  127.68  Intel Onboard Graphics  Intel Core i5
# 2      Notebook  141.21  Intel Onboard Graphics  Intel Core i5
# 3   MacBook Pro  220.53          AMD Radeon Pro  Intel Core i7
# 4   MacBook Pro  226.98  Intel Onboard Graphics  Intel Core i5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1274
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   company             1274 non-null   object
#  1   ram                 1274 non-null   int64
#  2   price_euros         1274 non-null   float64
#  3   ipspanel            1274 non-null   object
#  4   secondarystorage    1274 non-null   int64
#  5   primarystoragetype  1274 non-null   object
#  6   new_type_name       1274 non-null   object
#  7   ppi                 1274 non-null   float64
#  8   gpu_name            1274 non-null   object
#  9   cpu_name            1274 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 109.5+ KB

# %%
X = df.drop('price_euros', axis=1)
y = df['price_euros']

# %%
X.head()
# Out:
#   company  ram ipspanel  secondarystorage primarystoragetype new_type_name  \
# 0   Apple    8        1                 0                SSD   MacBook Pro
# 1   Apple    8        0                 0      Flash Storage   MacBook Air
# 2      HP    8        0                 0                SSD      Notebook
# 3   Apple   16        1                 0                SSD   MacBook Pro
# 4   Apple    8        1                 0                SSD   MacBook Pro
#
#       ppi                gpu_name       cpu_name
# 0  226.98  Intel Onboard Graphics  Intel Core i5
# 1  127.68  Intel Onboard Graphics  Intel Core i5
# 2  141.21  Intel Onboard Graphics  Intel Core i5
# 3  220.53          AMD Radeon Pro  Intel Core i7
# 4  226.98  Intel Onboard Graphics  Intel Core i5

# %%
X.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['ram', 'secondarystorage', 'ppi'], dtype='object')

# %%
X.select_dtypes(exclude=['int64', 'float64']).columns
# Out:
# Index(['company', 'ipspanel', 'primarystoragetype', 'new_type_name',
#        'gpu_name', 'cpu_name'],
#       dtype='object')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.base import RegressorMixin
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import HistGradientBoostingRegressor


# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=59)

# Preprocessing
numerical_features = ['ram', 'secondarystorage', 'ppi']
categorical_features = ['company', 'ipspanel', 'primarystoragetype', 'new_type_name',
       'gpu_name', 'cpu_name']

preprocessor = ColumnTransformer(
    transformers=[
        ('num', MinMaxScaler(), numerical_features),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_features)
    ]
)
# class SklearnCompatibleXGB(XGBRegressor, RegressorMixin):
#     pass
# Models
models = {
    "Linear Regression": LinearRegression(),
    "Lasso Regression": Lasso(),
    "Ridge Regression": Ridge(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "Random Forest": RandomForestRegressor(),
    # "XGBoost": XGBRegressor()
}

# Pipelines & Training
results = {}
for name, model in models.items():
    pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    mse = mean_squared_error(y_test, y_pred),
    r2  = r2_score(y_test, y_pred)
    print(f"{name} - Mean squared error: {mse}")
    print(f"{name} - R2 score: {r2}")
    print("*"*50)
# Out:
# Linear Regression - Mean squared error: (102009.62610756658,)
# Linear Regression - R2 score: 0.8106676455013015
# **************************************************
# Lasso Regression - Mean squared error: (99864.19708146228,)
# Lasso Regression - R2 score: 0.8146496141097724
# **************************************************
# Ridge Regression - Mean squared error: (97899.04880373122,)
# Ridge Regression - R2 score: 0.8182969772514582
# **************************************************
# Gradient Boosting - Mean squared error: (77019.24933170805,)
# Gradient Boosting - R2 score: 0.8570503944175034
# **************************************************
# Random Forest - Mean squared error: (62709.64455355111,)
# Random Forest - R2 score: 0.8836093699571003
# **************************************************

# %%
import dagshub
dagshub.init(repo_owner='tommydoan', repo_name='ML-Laptop-Price-Prediction-Regression-Algorism', mlflow=True)
# Out:
# Accessing as tommydoan
# Initialized MLflow to track repo "tommydoan/ML-Laptop-Price-Prediction-Regression-Algorism"
# Repository tommydoan/ML-Laptop-Price-Prediction-Regression-Algorism initialized!

# %%
import mlflow
import mlflow.sklearn
from sklearn.metrics import mean_squared_error, r2_score

# mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_tracking_uri("https://dagshub.com/tommydoan/ML-Laptop-Price-Prediction-Regression-Algorism.mlflow")
mlflow.set_experiment("ML-Laptop-Price-Prediction-Regression")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=59)

# Preprocessing
numerical_features = ['ram', 'secondarystorage', 'ppi']
categorical_features = ['company', 'ipspanel', 'primarystoragetype', 'new_type_name',
       'gpu_name', 'cpu_name']

# Dictionary to store results for comparison
results = []

# Start the main MLflow run
with mlflow.start_run(run_name="Main_Run"):
    # Preprocessing pipeline
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', MinMaxScaler(), numerical_features),
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
        ]
    )

    # Define models
    models = {
        "Linear Regression": LinearRegression(),
        "Lasso Regression": Lasso(),
        "Ridge Regression": Ridge(),
        "Random Forest": RandomForestRegressor(),
        "Gradient Boosting": GradientBoostingRegressor(),
    }

    # Train and log each model
    for model_name, model in models.items():
        with mlflow.start_run(nested=True, run_name=model_name):  # Start a nested run
            pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
            pipeline.fit(X_train, y_train)
            y_pred = pipeline.predict(X_test)

            # Calculate metrics
            mse = mean_squared_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            # Log parameters, metrics, and the model
            mlflow.log_param("model_name", model_name)
            mlflow.log_metric("mean_squared_error", mse)
            mlflow.log_metric("r2_score", r2)
            mlflow.sklearn.log_model(pipeline, artifact_path=f"{model_name}_model")

            # Save results for chart comparison
            results.append({"Model": model_name, "Mean Squared Error": mse, "R2 Score": r2})

# Create a comparison chart
results_df = pd.DataFrame(results)
print(results_df)

# Optional: Save the results for offline use or visualization
results_df.to_csv("model_comparison.csv", index=False)

mlflow.end_run()
# Out:
# 2025/01/22 22:48:06 INFO mlflow.tracking.fluent: Experiment with name 'ML-Laptop-Price-Prediction-Regression' does not exist. Creating a new experiment.
# 2025/01/22 22:48:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Linear Regression at: https://dagshub.com/tommydoan/ML-Laptop-Price-Prediction-Regression-Algorism.mlflow/#/experiments/0/runs/af0a3dc5723e427c80c7791656568870
# 🧪 View experiment at: https://dagshub.com/tommydoan/ML-Laptop-Price-Prediction-Regression-Algorism.mlflow/#/experiments/0
# 2025/01/22 22:48:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# ...

# %%
X[X['cpu_name']=="AMD FX"]
# Out:
#     company  ram ipspanel  secondarystorage primarystoragetype new_type_name  \
# 90     Asus    8        0                 0                HDD        Gaming
# 945  Lenovo   16        1              1024                SSD        Gaming
#
#         ppi       gpu_name cpu_name
# 90   141.21  AMD Radeon RX   AMD FX
# 945  141.21  AMD Radeon RX   AMD FX

# %%
# df = df[df['cpu_name']!="AMD FX"]

# %%
# df = df[df['company']!="Chuwi"]

# %%
df['company'].value_counts()
# Out:
# company
# Dell         291
# Lenovo       288
# HP           268
# Asus         151
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        8
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %%
X = df.drop('price_euros', axis=1)
y = df['price_euros']

# %%
score = []
numerical_features = ['ram', 'secondarystorage', 'ppi']
categorical_features = ['company', 'ipspanel', 'primarystoragetype', 'new_type_name',
       'gpu_name', 'cpu_name']

preprocessor = ColumnTransformer(
    transformers=[
        ('num', MinMaxScaler(), numerical_features),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_features)
    ]
)
for i in range(1000):
    model = RandomForestRegressor()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)
    pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('regressor', model)])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    score.append(r2_score(y_test, y_pred))

np.argmax(score)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# Define parameter grids for different models
param_grids = {
    "Random Forest": {
        "model__n_estimators": [50, 100, 200, 500],
        "model__max_depth": [None, 10, 20, 30],
        "model__min_samples_split": [2, 5, 10],
        "model__min_samples_leaf": [1, 2, 4],
    },
    "Gradient Boosting": {
        "model__n_estimators": [50, 100, 200, 500],
        "model__learning_rate": [0.01, 0.1, 0.2],
        "model__max_depth": [3, 5, 10],
        "model__min_samples_split": [2, 5, 10],
        "model__min_samples_leaf": [1, 2, 4],
    },
    "Lasso Regression": {
        "model__alpha": np.logspace(-4, 0, 50),
    },
    "Ridge Regression": {
        "model__alpha": np.logspace(-4, 0, 50),
    },
}

# Perform RandomizedSearchCV for each model
for name, model in models.items():
    pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
    param_grid = param_grids.get(name, {})  # Get the parameter grid for the model

    if param_grid:  # Only perform search if parameter grid exists
        random_search = RandomizedSearchCV(
            estimator=pipeline,
            param_distributions=param_grid,
            n_iter=20,  # Number of random configurations to test
            scoring="r2",  # Evaluation metric
            cv=5,  # Number of cross-validation folds
            verbose=2,
            random_state=42,
            n_jobs=-1
        )

        # Fit RandomizedSearchCV
        random_search.fit(X_train, y_train)

        # Best parameters and scores
        print(f"Best parameters for {name}: {random_search.best_params_}")
        print(f"Best R2 score for {name}: {random_search.best_score_}")
        print("*" * 50)
    else:
        print(f"No parameter grid defined for {name}. Skipping RandomizedSearchCV.")
# Out:
# No parameter grid defined for Linear Regression. Skipping RandomizedSearchCV.
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.100e+06, tolerance: 4.049e+04
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.015e+07, tolerance: 4.118e+04
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
import optuna
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

def objective(trial):
    # Define hyperparameters to tune
    model_name = trial.suggest_categorical("model", ["Random Forest", "Gradient Boosting", "Lasso Regression", "Ridge Regression"])

    if model_name == "Random Forest":
        n_estimators = trial.suggest_int("n_estimators", 50, 500)
        max_depth = trial.suggest_int("max_depth", 5, 50)
        min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 10)
        model = RandomForestRegressor(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            random_state=42
        )
    elif model_name == "Gradient Boosting":
        n_estimators = trial.suggest_int("n_estimators", 50, 500)
        learning_rate = trial.suggest_float("learning_rate", 0.01, 0.3)
        max_depth = trial.suggest_int("max_depth", 3, 20)
        model = GradientBoostingRegressor(
            n_estimators=n_estimators,
            learning_rate=learning_rate,
            max_depth=max_depth,
            random_state=42
        )
    elif model_name == "Lasso Regression":
        alpha = trial.suggest_float("alpha", 1e-4, 10, log=True)
        model = Lasso(alpha=alpha, random_state=42)
    elif model_name == "Ridge Regression":
        alpha = trial.suggest_float("alpha", 1e-4, 10, log=True)
        model = Ridge(alpha=alpha, random_state=42)

    # Define pipeline
    pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])

    # Cross-validation
    scores = cross_val_score(pipeline, X_train, y_train, scoring='r2', cv=5, n_jobs=-1)

    # Return the negative mean of the scores to maximize R²
    return scores.mean()

# Create an Optuna study
study = optuna.create_study(direction="maximize")  # Maximize R²
study.optimize(objective, n_trials=50)  # Adjust the number of trials as needed

# Display the best trial
print("Best trial:")
print(f"  Value: {study.best_trial.value}")
print(f"  Params: {study.best_trial.params}")

# Best model pipeline
best_params = study.best_trial.params
print("Best pipeline configuration found by Optuna:")
print(best_params)
# Out:
# [I 2025-01-22 21:43:34,443] A new study created in memory with name: no-name-8065ffb3-0ba7-4190-b414-4fd41b446650
# [I 2025-01-22 21:43:35,983] Trial 0 finished with value: 0.7750830966936453 and parameters: {'model': 'Random Forest', 'n_estimators': 478, 'max_depth': 43, 'min_samples_split': 18, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.7750830966936453.
# [I 2025-01-22 21:43:36,927] Trial 1 finished with value: 0.7400456572647506 and parameters: {'model': 'Random Forest', 'n_estimators': 420, 'max_depth': 36, 'min_samples_split': 3, 'min_samples_leaf': 8}. Best is trial 0 with value: 0.7750830966936453.
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.438e+07, tolerance: 4.405e+04
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
numerical_features = ['ram', 'secondarystorage', 'ppi']
categorical_features = ['company', 'ipspanel', 'primarystoragetype', 'new_type_name',
       'gpu_name', 'cpu_name']

preprocessor = ColumnTransformer(
    transformers=[
        ('num', MinMaxScaler(), numerical_features),
        ('cat', OneHotEncoder(drop='first',handle_unknown='ignore'), categorical_features)
    ]
)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=59)

# Preprocessing
numerical_features = ['ram', 'secondarystorage', 'ppi']
categorical_features = ['company', 'ipspanel', 'primarystoragetype', 'new_type_name',
       'gpu_name', 'cpu_name']
model = RandomForestRegressor()
pipeline_rdf = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
pipeline_rdf.fit(X_train, y_train)
y_pred = pipeline_rdf.predict(X_test)
mse = mean_squared_error(y_test, y_pred),
r2  = r2_score(y_test, y_pred)
print(f" Mean squared error: {mse}")
print(f" R2 score: {r2}")
# Out:
#  Mean squared error: (61681.23607996843,)
#  R2 score: 0.88551812117127

# %%
from joblib import dump

# dump(pipeline_rdf, "streamlit_app/artifact/pipeline_rdf.joblib")
dump(pipeline, "streamlit_app/artifact/pipeline.joblib")
# dump(df, "streamlit_app/artifact/dataframe.joblib")
# Out:
# ['streamlit_app/artifact/pipeline.joblib']

# %%
df.columns
# Out:
# Index(['company', 'ram', 'price_euros', 'ipspanel', 'secondarystorage',
#        'primarystoragetype', 'new_type_name', 'ppi', 'gpu_name', 'cpu_name'],
#       dtype='object')

# %%
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['ram', 'secondarystorage',
#                                                    'ppi']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['company', 'ipspanel',
#                                                    'primarystoragetype',
#                                                    'new_type_name', 'gpu_name',
#                                                    'cpu_name'])])),
#                 ('model', GradientBoostingRegressor())])

# %%
pipeline_rdf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['ram', 'secondarystorage',
#                                                    'ppi']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['company', 'ipspanel',
#                                                    'primarystoragetype',
#                                                    'new_type_name', 'gpu_name',
#                                                    'cpu_name'])])),
#                 ('model', RandomForestRegressor())])
